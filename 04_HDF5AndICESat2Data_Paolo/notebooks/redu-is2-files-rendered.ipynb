# %% [markdown]
# # Reducing ICESat-2 data files

# %% [markdown]
# * Select files of interest (segment and time)
# * Select area of interest (subset lon/lat)
# * Reduce selected files with variables of interest
# * Filter data and separate tracks into asc/des
# * Process/Read each file in parallel
# * Plot some data to check everything went well

# %%
# %matplotlib inline

# %% [markdown]
# ## How ICESat-2 files are organized
#
# ICESat-2 ground tracks are subsetted into granules (individual files)
#
# Granules are then grouped into latitudinal bands (segments)
#
# ![Segments](segments.png "Latitudinal bands (Segments)")
#
#
# File naming convention:
#
# `ATL06_20181120202321_08130101_001_01.h5`
#
# `ATL06_[yyyymmdd][hhmmss]_[RGTccss]_[vvv_rr].h5`
#
# where
#
# `ATL_06` => L3A Land Ice product
#
# `yyyymmdd` => Year, month, day of data acquisition
#
# `hhmmss` => Hour, minute, second of data acquisition
#
# `RGT` => Reference Ground Track
#
# `cc` => Cycle Number
#
# `ss` => Segment number (latitude band)
#
# `vvv_rr` => Version and revision numbers

# %% [markdown]
# ## Select files of interest
#
# We will use the **file name** info for this (no need to open the files).
#
# Alternatively, we could retrieve this info from the **Metadata**.
#
# To select files withint a time interval and segment, all we need is:
#
# `yyyymmdd, hhmmss, ss`

# %% [markdown]
# Let's firt get a list with all file names

# %%
import getpass


def list_files_local(path):
    """ Get file list form local folder. """
    from glob import glob
    return glob(path)


def list_files_s3(path, bucket):
    """ Get file list from Amazon S3. """
    import s3fs
    return s3fs.S3FileSystem().glob(path, bucket)


def list_files_ssh(path, host, user, pwd):
    """ Get file list from remote folder usgin SSH. """
    import paramiko

    # Create an SSH client instance.
    ssh = paramiko.SSHClient()

    # Create a 'host_keys' object
    # and load the local known hosts  
    host_keys = ssh.load_system_host_keys()

    # Connect to our client w/remote machine credentials
    ssh.connect(host, username=user, password=pwd)

    # Execute command on remote system,
    # and get input, output and error variables
    stdin, stdout, stderr = ssh.exec_command('ls '+path)

    # Iterate over stdout
    files = [line.strip('\n') for line in stdout]

    # Close the connection to client
    ssh.close()
    return files
    

if 1:
    path = 'data/*.h5'
    files = list_files_local(path)
    #files = !ls data/*.h5  # alternatively
    
elif 1:
    #path = 's3://pangeo-data-upload-oregon/icesat2/atl06/*.h5'
    path = 's3://pangeo-data-upload-oregon/icesat2/data-access-outputs/*.h5'
    bucket = 'pangeo-data-upload-oregon'
    files = list_files_s3(path, bucket)
       
else:    
    path = '/u/devon-r2/shared_data/icesat2/atl06/rel209/raw/*.h5'
    host = 'devon.jpl.nasa.gov'
    user = 'paolofer'
    pwd = getpass.getpass('Password:')
    files = list_files_ssh(path, host, user, pwd)
    

for f in files[:5]: print(f)
print('Total number of files:', len(files))
# Out:
# data/ATL06_20190101003047_00540212_209_01.h5
# data/ATL06_20190101002504_00540211_209_01.h5
# data/ATL06_20190101001723_00540210_209_01.h5
# data/ATL06_20181013235645_02340114_209_01.h5
# Total number of files: 4

# %% [markdown]
# Filter file names by segment and time interval

# %%
import os
import datetime as dt

# File name format: ATL06_[yyyymmdd][hhmmss]_[RGTccss]_[vvv_rr].h5

#NOTE: Need to simplify this function
def time_from_fname(fname):
    """ IS2 fname -> datatime object. """
    t = fname.split('_')[1]
    y, m , d, h, mn, s = t[:4], t[4:6], t[6:8], t[8:10], t[10:12], t[12:14]
    time = dt.datetime(int(y), int(m), int(d), int(h), int(mn), int(s))
    return time


def segment_from_fname(fname):
    """ IS2 fname -> segment number. """
    s = fname.split('_')[2]
    return int(s[-2:])


def select_files(files, segments=[10,11,12], t1=(2019,1,1), t2=(2019,2,1)):
    t1 = dt.datetime(*t1)
    t2 = dt.datetime(*t2)
    files_out = []
    for f in files:
        fname = os.path.basename(f)
        time = time_from_fname(fname)
        segment = segment_from_fname(fname)
        if t1 <= time <= t2 and segment in segments:
            files_out.append(f)
    return files_out

# %%
# Update file list
files = select_files(files, segments=[10,11,12], t1=(2019,1,1), t2=(2019,2,1))

for f in files[:5]: print(f)
print('Number of files:', len(files))
# Out:
# data/ATL06_20190101003047_00540212_209_01.h5
# data/ATL06_20190101002504_00540211_209_01.h5
# data/ATL06_20190101001723_00540210_209_01.h5
# Number of files: 3

# %% [markdown]
# ## Download files of interest

# %% [markdown]
#  **Tip!** You can download the entire folder from S3 using the `aws client`.
#
# Install and setup `aws client`:
# https://www.viget.com/articles/set-up-aws-cli-and-download-your-s3-files-from-the-command-line/
#
# List, download and upload folder content from the terminal:

# %%
# !aws s3 ls s3://pangeo-data-upload-oregon/icesat2/                              # list folder content
    
#!aws s3 sync s3://pangeo-data-upload-oregon/icesat2/data-access-outputs/ data/                     # download folder

#!aws --no-sign-request s3 sync data/ s3://pangeo-data-upload-oregon/icesat2/data-access-outputs/   # upload folder
# Out:
# Could not connect to the endpoint URL: "https://pangeo-data-upload-oregon.s3.Oregon.amazonaws.com/?list-type=2&prefix=icesat2%2F&delimiter=%2F&encoding-type=url"

# %% [markdown]
# Download selected files with Python

# %%
import getpass


def get_files_s3(files, opath, bucket='pangeo-data-upload-oregon'):
    """ Download files from Amazon S3. """
    import os
    import s3fs
    os.chdir(opath)  # change current dir
    for f in files: 
        print(f)
        s3fs.S3FileSystem().get(f, bucket)
    os.chdir('../')
    print('files saved ->', opath)
    
        
def get_files_ssh(files, opath, host, user, pwd):      
    import os
    files = ' '.join(files)
    os.system("rsync -Pav '%s@%s:%s' %s" % (user, host, files, opath))
    print('files saved ->', opath)
    

if 1:
    # We already downloaded the files for you -> /data
    pass

elif 0:
    get_files_s3(files, '/home/jovyan/intro-hdf5/notebooks/data/')
    
else:
    opath = 'data/'
    host = 'devon.jpl.nasa.gov'
    user = 'paolofer'
    pwd = getpass.getpass('Password:')
    get_files_ssh(files[:3], opath, host, user, pwd)

# %% [markdown]
# ## Reducing ICESat-2 files
#
# ***
# **NOTE:**
#
# + **This is neither the only nor the best way to handled ICESat-2 data files.**
#
# + **This is *one* way that works well for large-scale processing (e.g. full continent) on parallel machines (e.g. HPC clusters).**
#
# + **The idea is to (a) simplify the I/O of a complex workflow and (b) take advantage of embarrasingly parallelization.**
# ***

# %% [markdown]
# Let's check the ICESat-2 file structure

# %%
#!rm data/*_gt*
# !ls data/*.h5
# Out:
# data/ATL06_20181013235645_02340114_209_01.h5
# data/ATL06_20190101001723_00540210_209_01.h5
# data/ATL06_20190101002504_00540211_209_01.h5
# data/ATL06_20190101003047_00540212_209_01.h5

# %%
# !h5ls -r data/ATL06_20190101001723_00540210_209_01.h5
# Out:
# /                        Group
# /METADATA                Group
# /METADATA/AcquisitionInformation Group
# /METADATA/AcquisitionInformation/lidar Group
# /METADATA/AcquisitionInformation/lidarDocument Group
# /METADATA/AcquisitionInformation/platform Group
# /METADATA/AcquisitionInformation/platformDocument Group
# /METADATA/DataQuality    Group
# /METADATA/DataQuality/CompletenessOmission Group
# /METADATA/DataQuality/DomainConsistency Group
# /METADATA/DatasetIdentification Group
# /METADATA/Extent         Group
# /METADATA/Lineage        Group
# /METADATA/Lineage/ANC06-01 Group
# /METADATA/Lineage/ANC06-02 Group
# /METADATA/Lineage/ANC06-03 Group
# /METADATA/Lineage/ANC17  Group
# /METADATA/Lineage/ANC19  Group
# /METADATA/Lineage/ANC25-06 Group
# /METADATA/Lineage/ANC26-06 Group
# /METADATA/Lineage/ANC28  Group
# /METADATA/Lineage/ANC36-06 Group
# /METADATA/Lineage/ANC38-06 Group
# /METADATA/Lineage/ATL03  Group
# /METADATA/Lineage/ATL09  Group
# /METADATA/Lineage/Control Group
# /METADATA/ProcessStep    Group
# /METADATA/ProcessStep/Browse Group
# /METADATA/ProcessStep/Metadata Group
# /METADATA/ProcessStep/PGE Group
# /METADATA/ProcessStep/QA Group
# /METADATA/ProductSpecificationDocument Group
# /METADATA/QADatasetIdentification Group
# /METADATA/SeriesIdentification Group
# /ancillary_data          Group
# /ancillary_data/atlas_sdp_gps_epoch Dataset {1}
# /ancillary_data/control  Dataset {1}
# /ancillary_data/data_end_utc Dataset {1}
# /ancillary_data/data_start_utc Dataset {1}
# /ancillary_data/end_cycle Dataset {1}
# /ancillary_data/end_delta_time Dataset {1}
# /ancillary_data/end_geoseg Dataset {1}
# /ancillary_data/end_gpssow Dataset {1}
# /ancillary_data/end_gpsweek Dataset {1}
# /ancillary_data/end_orbit Dataset {1}
# /ancillary_data/end_region Dataset {1}
# /ancillary_data/end_rgt  Dataset {1}
# /ancillary_data/granule_end_utc Dataset {1}
# /ancillary_data/granule_start_utc Dataset {1}
# /ancillary_data/land_ice Group
# /ancillary_data/land_ice/dt_hist Dataset {1}
# /ancillary_data/land_ice/fit_maxiter Dataset {1}
# /ancillary_data/land_ice/fpb_maxiter Dataset {1}
# /ancillary_data/land_ice/max_res_ids Dataset {1}
# /ancillary_data/land_ice/maxiter Dataset {1}
# /ancillary_data/land_ice/min_dist Dataset {1}
# /ancillary_data/land_ice/min_gain_th Dataset {1}
# /ancillary_data/land_ice/min_n_pe Dataset {1}
# /ancillary_data/land_ice/min_n_sel Dataset {1}
# /ancillary_data/land_ice/min_signal_conf Dataset {1}
# /ancillary_data/land_ice/n_hist Dataset {1}
# /ancillary_data/land_ice/n_sigmas Dataset {1}
# /ancillary_data/land_ice/nhist_bins Dataset {1}
# /ancillary_data/land_ice/proc_interval Dataset {1}
# /ancillary_data/land_ice/rbin_width Dataset {1}
# /ancillary_data/land_ice/sigma_beam Dataset {1}
# /ancillary_data/land_ice/sigma_tx Dataset {1}
# /ancillary_data/land_ice/t_dead Dataset {1}
# /ancillary_data/land_ice/win_nsig Dataset {2}
# /ancillary_data/qa_at_interval Dataset {1}
# /ancillary_data/release  Dataset {1}
# /ancillary_data/start_cycle Dataset {1}
# /ancillary_data/start_delta_time Dataset {1}
# /ancillary_data/start_geoseg Dataset {1}
# /ancillary_data/start_gpssow Dataset {1}
# /ancillary_data/start_gpsweek Dataset {1}
# /ancillary_data/start_orbit Dataset {1}
# /ancillary_data/start_region Dataset {1}
# /ancillary_data/start_rgt Dataset {1}
# /ancillary_data/version  Dataset {1}
# /gt1l                    Group
# /gt1l/land_ice_segments  Group
# /gt1l/land_ice_segments/atl06_quality_summary Dataset {36131/Inf}
# /gt1l/land_ice_segments/bias_correction Group
# /gt1l/land_ice_segments/bias_correction/fpb_mean_corr Dataset {36131/Inf}
# /gt1l/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {36131/Inf}
# /gt1l/land_ice_segments/bias_correction/fpb_med_corr Dataset {36131/Inf}
# /gt1l/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {36131/Inf}
# /gt1l/land_ice_segments/bias_correction/fpb_n_corr Dataset {36131/Inf}
# /gt1l/land_ice_segments/bias_correction/med_r_fit Dataset {36131/Inf}
# /gt1l/land_ice_segments/bias_correction/tx_mean_corr Dataset {36131/Inf}
# /gt1l/land_ice_segments/bias_correction/tx_med_corr Dataset {36131/Inf}
# /gt1l/land_ice_segments/delta_time Dataset {36131/Inf}
# /gt1l/land_ice_segments/dem Group
# /gt1l/land_ice_segments/dem/dem_flag Dataset {36131/Inf}
# /gt1l/land_ice_segments/dem/dem_h Dataset {36131/Inf}
# /gt1l/land_ice_segments/dem/geoid_h Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics Group
# /gt1l/land_ice_segments/fit_statistics/dh_fit_dx Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/dh_fit_dy Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/h_expected_rms Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/h_mean Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/h_rms_misfit Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/h_robust_sprd Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/n_fit_photons Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/n_seg_pulses Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/sigma_h_mean Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/signal_selection_source Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/snr Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/snr_significance Dataset {36131/Inf}
# /gt1l/land_ice_segments/fit_statistics/w_surface_window_final Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical Group
# /gt1l/land_ice_segments/geophysical/bckgrd Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/bsnow_conf Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/bsnow_h Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/bsnow_od Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/cloud_flg_asr Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/cloud_flg_atm Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/dac Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/e_bckgrd Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/msw_flag Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/neutat_delay_total Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/r_eff Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/solar_azimuth Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/solar_elevation Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/tide_earth Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/tide_load Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/tide_ocean Dataset {36131/Inf}
# /gt1l/land_ice_segments/geophysical/tide_pole Dataset {36131/Inf}
# /gt1l/land_ice_segments/ground_track Group
# /gt1l/land_ice_segments/ground_track/ref_azimuth Dataset {36131/Inf}
# /gt1l/land_ice_segments/ground_track/ref_coelv Dataset {36131/Inf}
# /gt1l/land_ice_segments/ground_track/seg_azimuth Dataset {36131/Inf}
# /gt1l/land_ice_segments/ground_track/sigma_geo_at Dataset {36131/Inf}
# /gt1l/land_ice_segments/ground_track/sigma_geo_xt Dataset {36131/Inf}
# /gt1l/land_ice_segments/ground_track/x_atc Dataset {36131/Inf}
# /gt1l/land_ice_segments/ground_track/y_atc Dataset {36131/Inf}
# /gt1l/land_ice_segments/h_li Dataset {36131/Inf}
# /gt1l/land_ice_segments/h_li_sigma Dataset {36131/Inf}
# /gt1l/land_ice_segments/latitude Dataset {36131/Inf}
# /gt1l/land_ice_segments/longitude Dataset {36131/Inf}
# /gt1l/land_ice_segments/segment_id Dataset {36131/Inf}
# /gt1l/land_ice_segments/sigma_geo_h Dataset {36131/Inf}
# /gt1l/residual_histogram Group
# /gt1l/residual_histogram/bckgrd_per_bin Dataset {3469/Inf}
# /gt1l/residual_histogram/count Dataset {3469/Inf, 1000}
# /gt1l/residual_histogram/delta_time Dataset {3469/Inf}
# /gt1l/residual_histogram/dh Dataset {1000}
# /gt1l/residual_histogram/ds_segment_id Dataset {10}
# /gt1l/residual_histogram/lat_mean Dataset {3469/Inf}
# /gt1l/residual_histogram/lon_mean Dataset {3469/Inf}
# /gt1l/residual_histogram/pulse_count Dataset {3469/Inf}
# /gt1l/residual_histogram/segment_id_list Dataset {3469/Inf, 10}
# /gt1l/residual_histogram/x_atc_mean Dataset {3469/Inf}
# /gt1l/segment_quality    Group
# /gt1l/segment_quality/delta_time Dataset {133511/Inf}
# /gt1l/segment_quality/record_number Dataset {133511/Inf}
# /gt1l/segment_quality/reference_pt_lat Dataset {133511/Inf}
# /gt1l/segment_quality/reference_pt_lon Dataset {133511/Inf}
# /gt1l/segment_quality/segment_id Dataset {133511/Inf}
# /gt1l/segment_quality/signal_selection_source Dataset {133511/Inf}
# /gt1l/segment_quality/signal_selection_status Group
# /gt1l/segment_quality/signal_selection_status/signal_selection_status_all Dataset {133511/Inf}
# /gt1l/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {133511/Inf}
# /gt1l/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {133511/Inf}
# /gt1r                    Group
# /gt1r/land_ice_segments  Group
# /gt1r/land_ice_segments/atl06_quality_summary Dataset {36131/Inf}
# /gt1r/land_ice_segments/bias_correction Group
# /gt1r/land_ice_segments/bias_correction/fpb_mean_corr Dataset {36131/Inf}
# /gt1r/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {36131/Inf}
# /gt1r/land_ice_segments/bias_correction/fpb_med_corr Dataset {36131/Inf}
# /gt1r/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {36131/Inf}
# /gt1r/land_ice_segments/bias_correction/fpb_n_corr Dataset {36131/Inf}
# /gt1r/land_ice_segments/bias_correction/med_r_fit Dataset {36131/Inf}
# /gt1r/land_ice_segments/bias_correction/tx_mean_corr Dataset {36131/Inf}
# /gt1r/land_ice_segments/bias_correction/tx_med_corr Dataset {36131/Inf}
# /gt1r/land_ice_segments/delta_time Dataset {36131/Inf}
# /gt1r/land_ice_segments/dem Group
# /gt1r/land_ice_segments/dem/dem_flag Dataset {36131/Inf}
# /gt1r/land_ice_segments/dem/dem_h Dataset {36131/Inf}
# /gt1r/land_ice_segments/dem/geoid_h Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics Group
# /gt1r/land_ice_segments/fit_statistics/dh_fit_dx Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/dh_fit_dy Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/h_expected_rms Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/h_mean Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/h_rms_misfit Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/h_robust_sprd Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/n_fit_photons Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/n_seg_pulses Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/sigma_h_mean Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/signal_selection_source Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/snr Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/snr_significance Dataset {36131/Inf}
# /gt1r/land_ice_segments/fit_statistics/w_surface_window_final Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical Group
# /gt1r/land_ice_segments/geophysical/bckgrd Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/bsnow_conf Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/bsnow_h Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/bsnow_od Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/cloud_flg_asr Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/cloud_flg_atm Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/dac Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/e_bckgrd Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/msw_flag Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/neutat_delay_total Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/r_eff Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/solar_azimuth Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/solar_elevation Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/tide_earth Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/tide_load Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/tide_ocean Dataset {36131/Inf}
# /gt1r/land_ice_segments/geophysical/tide_pole Dataset {36131/Inf}
# /gt1r/land_ice_segments/ground_track Group
# /gt1r/land_ice_segments/ground_track/ref_azimuth Dataset {36131/Inf}
# /gt1r/land_ice_segments/ground_track/ref_coelv Dataset {36131/Inf}
# /gt1r/land_ice_segments/ground_track/seg_azimuth Dataset {36131/Inf}
# /gt1r/land_ice_segments/ground_track/sigma_geo_at Dataset {36131/Inf}
# /gt1r/land_ice_segments/ground_track/sigma_geo_xt Dataset {36131/Inf}
# /gt1r/land_ice_segments/ground_track/x_atc Dataset {36131/Inf}
# /gt1r/land_ice_segments/ground_track/y_atc Dataset {36131/Inf}
# /gt1r/land_ice_segments/h_li Dataset {36131/Inf}
# /gt1r/land_ice_segments/h_li_sigma Dataset {36131/Inf}
# /gt1r/land_ice_segments/latitude Dataset {36131/Inf}
# /gt1r/land_ice_segments/longitude Dataset {36131/Inf}
# /gt1r/land_ice_segments/segment_id Dataset {36131/Inf}
# /gt1r/land_ice_segments/sigma_geo_h Dataset {36131/Inf}
# /gt1r/residual_histogram Group
# /gt1r/residual_histogram/bckgrd_per_bin Dataset {3469/Inf}
# /gt1r/residual_histogram/count Dataset {3469/Inf, 1000}
# /gt1r/residual_histogram/delta_time Dataset {3469/Inf}
# /gt1r/residual_histogram/dh Dataset {1000}
# /gt1r/residual_histogram/ds_segment_id Dataset {10}
# /gt1r/residual_histogram/lat_mean Dataset {3469/Inf}
# /gt1r/residual_histogram/lon_mean Dataset {3469/Inf}
# /gt1r/residual_histogram/pulse_count Dataset {3469/Inf}
# /gt1r/residual_histogram/segment_id_list Dataset {3469/Inf, 10}
# /gt1r/residual_histogram/x_atc_mean Dataset {3469/Inf}
# /gt1r/segment_quality    Group
# /gt1r/segment_quality/delta_time Dataset {133511/Inf}
# /gt1r/segment_quality/record_number Dataset {133511/Inf}
# /gt1r/segment_quality/reference_pt_lat Dataset {133511/Inf}
# /gt1r/segment_quality/reference_pt_lon Dataset {133511/Inf}
# /gt1r/segment_quality/segment_id Dataset {133511/Inf}
# /gt1r/segment_quality/signal_selection_source Dataset {133511/Inf}
# /gt1r/segment_quality/signal_selection_status Group
# /gt1r/segment_quality/signal_selection_status/signal_selection_status_all Dataset {133511/Inf}
# /gt1r/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {133511/Inf}
# /gt1r/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {133511/Inf}
# /gt2l                    Group
# /gt2l/land_ice_segments  Group
# /gt2l/land_ice_segments/atl06_quality_summary Dataset {36353/Inf}
# /gt2l/land_ice_segments/bias_correction Group
# /gt2l/land_ice_segments/bias_correction/fpb_mean_corr Dataset {36353/Inf}
# /gt2l/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {36353/Inf}
# /gt2l/land_ice_segments/bias_correction/fpb_med_corr Dataset {36353/Inf}
# /gt2l/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {36353/Inf}
# /gt2l/land_ice_segments/bias_correction/fpb_n_corr Dataset {36353/Inf}
# /gt2l/land_ice_segments/bias_correction/med_r_fit Dataset {36353/Inf}
# /gt2l/land_ice_segments/bias_correction/tx_mean_corr Dataset {36353/Inf}
# /gt2l/land_ice_segments/bias_correction/tx_med_corr Dataset {36353/Inf}
# /gt2l/land_ice_segments/delta_time Dataset {36353/Inf}
# /gt2l/land_ice_segments/dem Group
# /gt2l/land_ice_segments/dem/dem_flag Dataset {36353/Inf}
# /gt2l/land_ice_segments/dem/dem_h Dataset {36353/Inf}
# /gt2l/land_ice_segments/dem/geoid_h Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics Group
# /gt2l/land_ice_segments/fit_statistics/dh_fit_dx Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/dh_fit_dy Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/h_expected_rms Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/h_mean Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/h_rms_misfit Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/h_robust_sprd Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/n_fit_photons Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/n_seg_pulses Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/sigma_h_mean Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/signal_selection_source Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/snr Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/snr_significance Dataset {36353/Inf}
# /gt2l/land_ice_segments/fit_statistics/w_surface_window_final Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical Group
# /gt2l/land_ice_segments/geophysical/bckgrd Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/bsnow_conf Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/bsnow_h Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/bsnow_od Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/cloud_flg_asr Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/cloud_flg_atm Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/dac Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/e_bckgrd Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/msw_flag Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/neutat_delay_total Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/r_eff Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/solar_azimuth Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/solar_elevation Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/tide_earth Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/tide_load Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/tide_ocean Dataset {36353/Inf}
# /gt2l/land_ice_segments/geophysical/tide_pole Dataset {36353/Inf}
# /gt2l/land_ice_segments/ground_track Group
# /gt2l/land_ice_segments/ground_track/ref_azimuth Dataset {36353/Inf}
# /gt2l/land_ice_segments/ground_track/ref_coelv Dataset {36353/Inf}
# /gt2l/land_ice_segments/ground_track/seg_azimuth Dataset {36353/Inf}
# /gt2l/land_ice_segments/ground_track/sigma_geo_at Dataset {36353/Inf}
# /gt2l/land_ice_segments/ground_track/sigma_geo_xt Dataset {36353/Inf}
# /gt2l/land_ice_segments/ground_track/x_atc Dataset {36353/Inf}
# /gt2l/land_ice_segments/ground_track/y_atc Dataset {36353/Inf}
# /gt2l/land_ice_segments/h_li Dataset {36353/Inf}
# /gt2l/land_ice_segments/h_li_sigma Dataset {36353/Inf}
# /gt2l/land_ice_segments/latitude Dataset {36353/Inf}
# /gt2l/land_ice_segments/longitude Dataset {36353/Inf}
# /gt2l/land_ice_segments/segment_id Dataset {36353/Inf}
# /gt2l/land_ice_segments/sigma_geo_h Dataset {36353/Inf}
# /gt2l/residual_histogram Group
# /gt2l/residual_histogram/bckgrd_per_bin Dataset {3495/Inf}
# /gt2l/residual_histogram/count Dataset {3495/Inf, 1000}
# /gt2l/residual_histogram/delta_time Dataset {3495/Inf}
# /gt2l/residual_histogram/dh Dataset {1000}
# /gt2l/residual_histogram/ds_segment_id Dataset {10}
# /gt2l/residual_histogram/lat_mean Dataset {3495/Inf}
# /gt2l/residual_histogram/lon_mean Dataset {3495/Inf}
# /gt2l/residual_histogram/pulse_count Dataset {3495/Inf}
# /gt2l/residual_histogram/segment_id_list Dataset {3495/Inf, 10}
# /gt2l/residual_histogram/x_atc_mean Dataset {3495/Inf}
# /gt2l/segment_quality    Group
# /gt2l/segment_quality/delta_time Dataset {103511/Inf}
# /gt2l/segment_quality/record_number Dataset {103511/Inf}
# /gt2l/segment_quality/reference_pt_lat Dataset {103511/Inf}
# /gt2l/segment_quality/reference_pt_lon Dataset {103511/Inf}
# /gt2l/segment_quality/segment_id Dataset {103511/Inf}
# /gt2l/segment_quality/signal_selection_source Dataset {103511/Inf}
# /gt2l/segment_quality/signal_selection_status Group
# /gt2l/segment_quality/signal_selection_status/signal_selection_status_all Dataset {103511/Inf}
# /gt2l/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {103511/Inf}
# /gt2l/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {103511/Inf}
# /gt2r                    Group
# /gt2r/land_ice_segments  Group
# /gt2r/land_ice_segments/atl06_quality_summary Dataset {36353/Inf}
# /gt2r/land_ice_segments/bias_correction Group
# /gt2r/land_ice_segments/bias_correction/fpb_mean_corr Dataset {36353/Inf}
# /gt2r/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {36353/Inf}
# /gt2r/land_ice_segments/bias_correction/fpb_med_corr Dataset {36353/Inf}
# /gt2r/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {36353/Inf}
# /gt2r/land_ice_segments/bias_correction/fpb_n_corr Dataset {36353/Inf}
# /gt2r/land_ice_segments/bias_correction/med_r_fit Dataset {36353/Inf}
# /gt2r/land_ice_segments/bias_correction/tx_mean_corr Dataset {36353/Inf}
# /gt2r/land_ice_segments/bias_correction/tx_med_corr Dataset {36353/Inf}
# /gt2r/land_ice_segments/delta_time Dataset {36353/Inf}
# /gt2r/land_ice_segments/dem Group
# /gt2r/land_ice_segments/dem/dem_flag Dataset {36353/Inf}
# /gt2r/land_ice_segments/dem/dem_h Dataset {36353/Inf}
# /gt2r/land_ice_segments/dem/geoid_h Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics Group
# /gt2r/land_ice_segments/fit_statistics/dh_fit_dx Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/dh_fit_dy Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/h_expected_rms Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/h_mean Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/h_rms_misfit Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/h_robust_sprd Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/n_fit_photons Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/n_seg_pulses Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/sigma_h_mean Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/signal_selection_source Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/snr Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/snr_significance Dataset {36353/Inf}
# /gt2r/land_ice_segments/fit_statistics/w_surface_window_final Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical Group
# /gt2r/land_ice_segments/geophysical/bckgrd Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/bsnow_conf Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/bsnow_h Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/bsnow_od Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/cloud_flg_asr Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/cloud_flg_atm Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/dac Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/e_bckgrd Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/msw_flag Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/neutat_delay_total Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/r_eff Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/solar_azimuth Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/solar_elevation Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/tide_earth Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/tide_load Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/tide_ocean Dataset {36353/Inf}
# /gt2r/land_ice_segments/geophysical/tide_pole Dataset {36353/Inf}
# /gt2r/land_ice_segments/ground_track Group
# /gt2r/land_ice_segments/ground_track/ref_azimuth Dataset {36353/Inf}
# /gt2r/land_ice_segments/ground_track/ref_coelv Dataset {36353/Inf}
# /gt2r/land_ice_segments/ground_track/seg_azimuth Dataset {36353/Inf}
# /gt2r/land_ice_segments/ground_track/sigma_geo_at Dataset {36353/Inf}
# /gt2r/land_ice_segments/ground_track/sigma_geo_xt Dataset {36353/Inf}
# /gt2r/land_ice_segments/ground_track/x_atc Dataset {36353/Inf}
# /gt2r/land_ice_segments/ground_track/y_atc Dataset {36353/Inf}
# /gt2r/land_ice_segments/h_li Dataset {36353/Inf}
# /gt2r/land_ice_segments/h_li_sigma Dataset {36353/Inf}
# /gt2r/land_ice_segments/latitude Dataset {36353/Inf}
# /gt2r/land_ice_segments/longitude Dataset {36353/Inf}
# /gt2r/land_ice_segments/segment_id Dataset {36353/Inf}
# /gt2r/land_ice_segments/sigma_geo_h Dataset {36353/Inf}
# /gt2r/residual_histogram Group
# /gt2r/residual_histogram/bckgrd_per_bin Dataset {3495/Inf}
# /gt2r/residual_histogram/count Dataset {3495/Inf, 1000}
# /gt2r/residual_histogram/delta_time Dataset {3495/Inf}
# /gt2r/residual_histogram/dh Dataset {1000}
# /gt2r/residual_histogram/ds_segment_id Dataset {10}
# /gt2r/residual_histogram/lat_mean Dataset {3495/Inf}
# /gt2r/residual_histogram/lon_mean Dataset {3495/Inf}
# /gt2r/residual_histogram/pulse_count Dataset {3495/Inf}
# /gt2r/residual_histogram/segment_id_list Dataset {3495/Inf, 10}
# /gt2r/residual_histogram/x_atc_mean Dataset {3495/Inf}
# /gt2r/segment_quality    Group
# /gt2r/segment_quality/delta_time Dataset {103511/Inf}
# /gt2r/segment_quality/record_number Dataset {103511/Inf}
# /gt2r/segment_quality/reference_pt_lat Dataset {103511/Inf}
# /gt2r/segment_quality/reference_pt_lon Dataset {103511/Inf}
# /gt2r/segment_quality/segment_id Dataset {103511/Inf}
# /gt2r/segment_quality/signal_selection_source Dataset {103511/Inf}
# /gt2r/segment_quality/signal_selection_status Group
# /gt2r/segment_quality/signal_selection_status/signal_selection_status_all Dataset {103511/Inf}
# /gt2r/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {103511/Inf}
# /gt2r/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {103511/Inf}
# /gt3l                    Group
# /gt3l/land_ice_segments  Group
# /gt3l/land_ice_segments/atl06_quality_summary Dataset {36330/Inf}
# /gt3l/land_ice_segments/bias_correction Group
# /gt3l/land_ice_segments/bias_correction/fpb_mean_corr Dataset {36330/Inf}
# /gt3l/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {36330/Inf}
# /gt3l/land_ice_segments/bias_correction/fpb_med_corr Dataset {36330/Inf}
# /gt3l/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {36330/Inf}
# /gt3l/land_ice_segments/bias_correction/fpb_n_corr Dataset {36330/Inf}
# /gt3l/land_ice_segments/bias_correction/med_r_fit Dataset {36330/Inf}
# /gt3l/land_ice_segments/bias_correction/tx_mean_corr Dataset {36330/Inf}
# /gt3l/land_ice_segments/bias_correction/tx_med_corr Dataset {36330/Inf}
# /gt3l/land_ice_segments/delta_time Dataset {36330/Inf}
# /gt3l/land_ice_segments/dem Group
# /gt3l/land_ice_segments/dem/dem_flag Dataset {36330/Inf}
# /gt3l/land_ice_segments/dem/dem_h Dataset {36330/Inf}
# /gt3l/land_ice_segments/dem/geoid_h Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics Group
# /gt3l/land_ice_segments/fit_statistics/dh_fit_dx Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/dh_fit_dy Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/h_expected_rms Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/h_mean Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/h_rms_misfit Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/h_robust_sprd Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/n_fit_photons Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/n_seg_pulses Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/sigma_h_mean Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/signal_selection_source Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/snr Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/snr_significance Dataset {36330/Inf}
# /gt3l/land_ice_segments/fit_statistics/w_surface_window_final Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical Group
# /gt3l/land_ice_segments/geophysical/bckgrd Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/bsnow_conf Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/bsnow_h Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/bsnow_od Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/cloud_flg_asr Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/cloud_flg_atm Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/dac Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/e_bckgrd Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/msw_flag Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/neutat_delay_total Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/r_eff Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/solar_azimuth Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/solar_elevation Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/tide_earth Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/tide_load Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/tide_ocean Dataset {36330/Inf}
# /gt3l/land_ice_segments/geophysical/tide_pole Dataset {36330/Inf}
# /gt3l/land_ice_segments/ground_track Group
# /gt3l/land_ice_segments/ground_track/ref_azimuth Dataset {36330/Inf}
# /gt3l/land_ice_segments/ground_track/ref_coelv Dataset {36330/Inf}
# /gt3l/land_ice_segments/ground_track/seg_azimuth Dataset {36330/Inf}
# /gt3l/land_ice_segments/ground_track/sigma_geo_at Dataset {36330/Inf}
# /gt3l/land_ice_segments/ground_track/sigma_geo_xt Dataset {36330/Inf}
# /gt3l/land_ice_segments/ground_track/x_atc Dataset {36330/Inf}
# /gt3l/land_ice_segments/ground_track/y_atc Dataset {36330/Inf}
# /gt3l/land_ice_segments/h_li Dataset {36330/Inf}
# /gt3l/land_ice_segments/h_li_sigma Dataset {36330/Inf}
# /gt3l/land_ice_segments/latitude Dataset {36330/Inf}
# /gt3l/land_ice_segments/longitude Dataset {36330/Inf}
# /gt3l/land_ice_segments/segment_id Dataset {36330/Inf}
# /gt3l/land_ice_segments/sigma_geo_h Dataset {36330/Inf}
# /gt3l/residual_histogram Group
# /gt3l/residual_histogram/bckgrd_per_bin Dataset {3495/Inf}
# /gt3l/residual_histogram/count Dataset {3495/Inf, 1000}
# /gt3l/residual_histogram/delta_time Dataset {3495/Inf}
# /gt3l/residual_histogram/dh Dataset {1000}
# /gt3l/residual_histogram/ds_segment_id Dataset {10}
# /gt3l/residual_histogram/lat_mean Dataset {3495/Inf}
# /gt3l/residual_histogram/lon_mean Dataset {3495/Inf}
# /gt3l/residual_histogram/pulse_count Dataset {3495/Inf}
# /gt3l/residual_histogram/segment_id_list Dataset {3495/Inf, 10}
# /gt3l/residual_histogram/x_atc_mean Dataset {3495/Inf}
# /gt3l/segment_quality    Group
# /gt3l/segment_quality/delta_time Dataset {93511/Inf}
# /gt3l/segment_quality/record_number Dataset {93511/Inf}
# /gt3l/segment_quality/reference_pt_lat Dataset {93511/Inf}
# /gt3l/segment_quality/reference_pt_lon Dataset {93511/Inf}
# /gt3l/segment_quality/segment_id Dataset {93511/Inf}
# /gt3l/segment_quality/signal_selection_source Dataset {93511/Inf}
# /gt3l/segment_quality/signal_selection_status Group
# /gt3l/segment_quality/signal_selection_status/signal_selection_status_all Dataset {93511/Inf}
# /gt3l/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {93511/Inf}
# /gt3l/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {93511/Inf}
# /gt3r                    Group
# /gt3r/land_ice_segments  Group
# /gt3r/land_ice_segments/atl06_quality_summary Dataset {36330/Inf}
# /gt3r/land_ice_segments/bias_correction Group
# /gt3r/land_ice_segments/bias_correction/fpb_mean_corr Dataset {36330/Inf}
# /gt3r/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {36330/Inf}
# /gt3r/land_ice_segments/bias_correction/fpb_med_corr Dataset {36330/Inf}
# /gt3r/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {36330/Inf}
# /gt3r/land_ice_segments/bias_correction/fpb_n_corr Dataset {36330/Inf}
# /gt3r/land_ice_segments/bias_correction/med_r_fit Dataset {36330/Inf}
# /gt3r/land_ice_segments/bias_correction/tx_mean_corr Dataset {36330/Inf}
# /gt3r/land_ice_segments/bias_correction/tx_med_corr Dataset {36330/Inf}
# /gt3r/land_ice_segments/delta_time Dataset {36330/Inf}
# /gt3r/land_ice_segments/dem Group
# /gt3r/land_ice_segments/dem/dem_flag Dataset {36330/Inf}
# /gt3r/land_ice_segments/dem/dem_h Dataset {36330/Inf}
# /gt3r/land_ice_segments/dem/geoid_h Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics Group
# /gt3r/land_ice_segments/fit_statistics/dh_fit_dx Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/dh_fit_dy Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/h_expected_rms Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/h_mean Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/h_rms_misfit Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/h_robust_sprd Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/n_fit_photons Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/n_seg_pulses Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/sigma_h_mean Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/signal_selection_source Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/snr Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/snr_significance Dataset {36330/Inf}
# /gt3r/land_ice_segments/fit_statistics/w_surface_window_final Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical Group
# /gt3r/land_ice_segments/geophysical/bckgrd Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/bsnow_conf Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/bsnow_h Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/bsnow_od Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/cloud_flg_asr Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/cloud_flg_atm Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/dac Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/e_bckgrd Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/msw_flag Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/neutat_delay_total Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/r_eff Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/solar_azimuth Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/solar_elevation Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/tide_earth Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/tide_load Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/tide_ocean Dataset {36330/Inf}
# /gt3r/land_ice_segments/geophysical/tide_pole Dataset {36330/Inf}
# /gt3r/land_ice_segments/ground_track Group
# /gt3r/land_ice_segments/ground_track/ref_azimuth Dataset {36330/Inf}
# /gt3r/land_ice_segments/ground_track/ref_coelv Dataset {36330/Inf}
# /gt3r/land_ice_segments/ground_track/seg_azimuth Dataset {36330/Inf}
# /gt3r/land_ice_segments/ground_track/sigma_geo_at Dataset {36330/Inf}
# /gt3r/land_ice_segments/ground_track/sigma_geo_xt Dataset {36330/Inf}
# /gt3r/land_ice_segments/ground_track/x_atc Dataset {36330/Inf}
# /gt3r/land_ice_segments/ground_track/y_atc Dataset {36330/Inf}
# /gt3r/land_ice_segments/h_li Dataset {36330/Inf}
# /gt3r/land_ice_segments/h_li_sigma Dataset {36330/Inf}
# /gt3r/land_ice_segments/latitude Dataset {36330/Inf}
# /gt3r/land_ice_segments/longitude Dataset {36330/Inf}
# /gt3r/land_ice_segments/segment_id Dataset {36330/Inf}
# /gt3r/land_ice_segments/sigma_geo_h Dataset {36330/Inf}
# /gt3r/residual_histogram Group
# /gt3r/residual_histogram/bckgrd_per_bin Dataset {3495/Inf}
# /gt3r/residual_histogram/count Dataset {3495/Inf, 1000}
# /gt3r/residual_histogram/delta_time Dataset {3495/Inf}
# /gt3r/residual_histogram/dh Dataset {1000}
# /gt3r/residual_histogram/ds_segment_id Dataset {10}
# /gt3r/residual_histogram/lat_mean Dataset {3495/Inf}
# /gt3r/residual_histogram/lon_mean Dataset {3495/Inf}
# /gt3r/residual_histogram/pulse_count Dataset {3495/Inf}
# /gt3r/residual_histogram/segment_id_list Dataset {3495/Inf, 10}
# /gt3r/residual_histogram/x_atc_mean Dataset {3495/Inf}
# /gt3r/segment_quality    Group
# /gt3r/segment_quality/delta_time Dataset {93511/Inf}
# /gt3r/segment_quality/record_number Dataset {93511/Inf}
# /gt3r/segment_quality/reference_pt_lat Dataset {93511/Inf}
# /gt3r/segment_quality/reference_pt_lon Dataset {93511/Inf}
# /gt3r/segment_quality/segment_id Dataset {93511/Inf}
# /gt3r/segment_quality/signal_selection_source Dataset {93511/Inf}
# /gt3r/segment_quality/signal_selection_status Group
# /gt3r/segment_quality/signal_selection_status/signal_selection_status_all Dataset {93511/Inf}
# /gt3r/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {93511/Inf}
# /gt3r/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {93511/Inf}
# /orbit_info              Group
# /orbit_info/crossing_time Dataset {1/Inf}
# /orbit_info/cycle_number Dataset {1/Inf}
# /orbit_info/lan          Dataset {1/Inf}
# /orbit_info/orbit_number Dataset {1/Inf}
# /orbit_info/rgt          Dataset {1/Inf}
# /orbit_info/sc_orient    Dataset {1/Inf}
# /orbit_info/sc_orient_time Dataset {1/Inf}
# /quality_assessment      Group
# /quality_assessment/gt1l Group
# /quality_assessment/gt1l/delta_time Dataset {287/Inf}
# /quality_assessment/gt1l/lat_mean Dataset {287/Inf}
# /quality_assessment/gt1l/lon_mean Dataset {287/Inf}
# /quality_assessment/gt1l/signal_selection_source_fraction_0 Dataset {287/Inf}
# /quality_assessment/gt1l/signal_selection_source_fraction_1 Dataset {287/Inf}
# /quality_assessment/gt1l/signal_selection_source_fraction_2 Dataset {287/Inf}
# /quality_assessment/gt1l/signal_selection_source_fraction_3 Dataset {287/Inf}
# /quality_assessment/gt1r Group
# /quality_assessment/gt1r/delta_time Dataset {287/Inf}
# /quality_assessment/gt1r/lat_mean Dataset {287/Inf}
# /quality_assessment/gt1r/lon_mean Dataset {287/Inf}
# /quality_assessment/gt1r/signal_selection_source_fraction_0 Dataset {287/Inf}
# /quality_assessment/gt1r/signal_selection_source_fraction_1 Dataset {287/Inf}
# /quality_assessment/gt1r/signal_selection_source_fraction_2 Dataset {287/Inf}
# /quality_assessment/gt1r/signal_selection_source_fraction_3 Dataset {287/Inf}
# /quality_assessment/gt2l Group
# /quality_assessment/gt2l/delta_time Dataset {287/Inf}
# /quality_assessment/gt2l/lat_mean Dataset {287/Inf}
# /quality_assessment/gt2l/lon_mean Dataset {287/Inf}
# /quality_assessment/gt2l/signal_selection_source_fraction_0 Dataset {287/Inf}
# /quality_assessment/gt2l/signal_selection_source_fraction_1 Dataset {287/Inf}
# /quality_assessment/gt2l/signal_selection_source_fraction_2 Dataset {287/Inf}
# /quality_assessment/gt2l/signal_selection_source_fraction_3 Dataset {287/Inf}
# /quality_assessment/gt2r Group
# /quality_assessment/gt2r/delta_time Dataset {287/Inf}
# /quality_assessment/gt2r/lat_mean Dataset {287/Inf}
# /quality_assessment/gt2r/lon_mean Dataset {287/Inf}
# /quality_assessment/gt2r/signal_selection_source_fraction_0 Dataset {287/Inf}
# /quality_assessment/gt2r/signal_selection_source_fraction_1 Dataset {287/Inf}
# /quality_assessment/gt2r/signal_selection_source_fraction_2 Dataset {287/Inf}
# /quality_assessment/gt2r/signal_selection_source_fraction_3 Dataset {287/Inf}
# /quality_assessment/gt3l Group
# /quality_assessment/gt3l/delta_time Dataset {287/Inf}
# /quality_assessment/gt3l/lat_mean Dataset {287/Inf}
# /quality_assessment/gt3l/lon_mean Dataset {287/Inf}
# /quality_assessment/gt3l/signal_selection_source_fraction_0 Dataset {287/Inf}
# /quality_assessment/gt3l/signal_selection_source_fraction_1 Dataset {287/Inf}
# /quality_assessment/gt3l/signal_selection_source_fraction_2 Dataset {287/Inf}
# /quality_assessment/gt3l/signal_selection_source_fraction_3 Dataset {287/Inf}
# /quality_assessment/gt3r Group
# /quality_assessment/gt3r/delta_time Dataset {287/Inf}
# /quality_assessment/gt3r/lat_mean Dataset {287/Inf}
# /quality_assessment/gt3r/lon_mean Dataset {287/Inf}
# /quality_assessment/gt3r/signal_selection_source_fraction_0 Dataset {287/Inf}
# /quality_assessment/gt3r/signal_selection_source_fraction_1 Dataset {287/Inf}
# /quality_assessment/gt3r/signal_selection_source_fraction_2 Dataset {287/Inf}
# /quality_assessment/gt3r/signal_selection_source_fraction_3 Dataset {287/Inf}
# /quality_assessment/qa_granule_fail_reason Dataset {1}
# /quality_assessment/qa_granule_pass_fail Dataset {1}

# %% [markdown]
# Let's code a simple reader that:
#
# - Select variables of interest (x, y, t, h...)
# - Filter data points based on quality flag and bbox
# - Separate into beams and ascending/descending tracks
# - Save data to a simpler HDF5 structure (redundancy/efficiency)

# %% [markdown]
# Some utility functions

# %%
import pyproj
from astropy.time import Time

def gps2dyr(time):
    """ Converte GPS time to decimal years. """
    return Time(time, format='gps').decimalyear


def track_type(time, lat, tmax=1):
    """
    Separate tracks into ascending and descending.
    
    Defines tracks as segments with time breaks > tmax,
    and tests whether lat increases or decreases w/time.
    """
    tracks = np.zeros(lat.shape)  # generate track segment
    tracks[0:np.argmax(np.abs(lat))] = 1  # set values for segment
    i_asc = np.zeros(tracks.shape, dtype=bool)  # output index array

    # Loop trough individual secments
    for track in np.unique(tracks):
    
        i_track, = np.where(track == tracks)  # get all pts from seg
    
        if len(i_track) < 2: continue
    
        # Test if lat increases (asc) or decreases (des) w/time
        i_min = time[i_track].argmin()
        i_max = time[i_track].argmax()
        lat_diff = lat[i_track][i_max] - lat[i_track][i_min]
    
        # Determine track type
        if lat_diff > 0:  i_asc[i_track] = True
    
    return i_asc, np.invert(i_asc)  # index vectors


def transform_coord(proj1, proj2, x, y):
    """
    Transform coordinates from proj1 to proj2 (EPSG num).

    Example EPSG projs:
        Geodetic (lon/lat): 4326
        Polar Stereo AnIS (x/y): 3031
        Polar Stereo GrIS (x/y): 3413
    """
    # Set full EPSG projection strings
    proj1 = pyproj.Proj("+init=EPSG:"+str(proj1))
    proj2 = pyproj.Proj("+init=EPSG:"+str(proj2))
    return pyproj.transform(proj1, proj2, x, y)  # convert

# %% [markdown]
# The simple reader

# %%
import h5py
import numpy as np

def read_atl06(fname, bbox=None):
    """ 
    Read 1 ATL06 file and output 6 reduced files. 
    
    Extract variables of interest and separate the ATL06 file 
    into each beam (ground track) and ascending/descending orbits.
    """

    # Each beam is a group
    group = ['/gt1l', '/gt1r', '/gt2l', '/gt2r', '/gt3l', '/gt3r']

    # Loop trough beams
    for k,g in enumerate(group):
    
        #-----------------------------------#
        # 1) Read in data for a single beam #
        #-----------------------------------#
    
        # Load variables into memory (more can be added!)
        with h5py.File(fname, 'r') as fi:
            lat = fi[g+'/land_ice_segments/latitude'][:]
            lon = fi[g+'/land_ice_segments/longitude'][:]
            h_li = fi[g+'/land_ice_segments/h_li'][:]
            s_li = fi[g+'/land_ice_segments/h_li_sigma'][:]
            t_dt = fi[g+'/land_ice_segments/delta_time'][:]
            q_flag = fi[g+'/land_ice_segments/atl06_quality_summary'][:]
            s_fg = fi[g+'/land_ice_segments/fit_statistics/signal_selection_source'][:]
            snr = fi[g+'/land_ice_segments/fit_statistics/snr_significance'][:]
            h_rb = fi[g+'/land_ice_segments/fit_statistics/h_robust_sprd'][:]
            dac = fi[g+'/land_ice_segments/geophysical/dac'][:]
            f_sn = fi[g+'/land_ice_segments/geophysical/bsnow_conf'][:]
            dh_fit_dx = fi[g+'/land_ice_segments/fit_statistics/dh_fit_dx'][:]
            tide_earth = fi[g+'/land_ice_segments/geophysical/tide_earth'][:]
            tide_load = fi[g+'/land_ice_segments/geophysical/tide_load'][:]
            tide_ocean = fi[g+'/land_ice_segments/geophysical/tide_ocean'][:]
            tide_pole = fi[g+'/land_ice_segments/geophysical/tide_pole'][:]
            t_ref = fi['/ancillary_data/atlas_sdp_gps_epoch'][:]
            rgt = fi['/orbit_info/rgt'][:] * np.ones(len(lat))
            orb = np.full_like(h_li, k)

        #---------------------------------------------#
        # 2) Filter data according region and quality #
        #---------------------------------------------#
        
        # Select a region of interest
        if bbox:
            lonmin, lonmax, latmin, latmax = bbox
            bbox_mask = (lon >= lonmin) & (lon <= lonmax) & \
                        (lat >= latmin) & (lat <= latmax)
        else:
            bbox_mask = np.ones_like(lat, dtype=bool)  # get all
            
        # Only keep good data, and data inside bbox
        mask = (q_flag == 0) & (np.abs(h_li) < 10e3) & (bbox_mask == 1)
        
        # Update variables
        lat, lon, h_li, s_li, t_dt, h_rb, s_fg, snr, q_flag, f_sn, \
            tide_earth, tide_load, tide_ocean, tide_pole, dac, rgt, orb = \
                lat[mask], lon[mask], h_li[mask], s_li[mask], t_dt[mask], \
                h_rb[mask], s_fg[mask], snr[mask], q_flag[mask], f_sn[mask], \
                tide_earth[mask], tide_load[mask], tide_ocean[mask], \
                tide_pole[mask], dac[mask], rgt[mask], orb[mask]

        # Test for no data
        if len(h_li) == 0: continue

        #-------------------------------------#
        # 3) Convert time and separate tracks #
        #-------------------------------------#
        
        # Time in GPS seconds (secs sinde 1980...)
        t_gps = t_ref + t_dt

        # Time in decimal years
        t_year = gps2dyr(t_gps)

        # Determine orbit type
        i_asc, i_des = track_type(t_year, lat)
        
        #-----------------------#
        # 4) Save selected data #
        #-----------------------#
        
        # Define output file name
        ofile = fname.replace('.h5', '_'+g[1:]+'.h5')
                
        # Save variables
        with h5py.File(ofile, 'w') as f:
            f['orbit'] = orb
            f['lon'] = lon
            f['lat'] = lat
            f['h_elv'] = h_li
            f['t_year'] = t_year
            f['t_sec'] = t_gps
            f['s_elv'] = s_li
            f['h_rb'] = h_rb
            f['s_fg'] = s_fg
            f['snr'] = snr
            f['q_flg'] = q_flag
            f['f_sn'] = f_sn
            f['tide_load'] = tide_load
            f['tide_ocean'] = tide_ocean
            f['tide_pole'] = tide_pole
            f['tide_earth'] = tide_earth
            f['dac'] = dac
            f['rgt'] = rgt
            f['trk_type'] = i_asc

            print('out ->', ofile)

# %% [markdown]
# ## Simple parallelization
#
# * If your problem is embarrasingly parallel, it's easy to parallelize
# * We can use the very simple and lightweight `joblib` library
# * There is no need to modify your code!
#
# Read more: [https://joblib.readthedocs.io](https://joblib.readthedocs.io)

# %% [markdown]
# (Let's check the available resources first)

# %%
njobs = 3

#files = list_files_local('data/*_01.h5')  # we already created our file list

bbox = None #[-1124782, 81623, -919821, -96334]  # Kamb bounding box

if njobs == 1:
    print('running in serial ...')
    [read_atl06(f, bbox) for f in files]

else:
    print('running in parallel (%d jobs) ...' % njobs)
    from joblib import Parallel, delayed
    Parallel(n_jobs=njobs, verbose=5)(delayed(read_atl06)(f, bbox) for f in files)
# Out:
# running in parallel (3 jobs) ...
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:    0.6s finished

# %% [markdown]
# Let's check our created files

# %%
# !ls data/*.h5
# Out:
# data/ATL06_20181013235645_02340114_209_01.h5
# data/ATL06_20190101001723_00540210_209_01.h5
# data/ATL06_20190101001723_00540210_209_01_gt1l.h5
# data/ATL06_20190101001723_00540210_209_01_gt1r.h5
# data/ATL06_20190101001723_00540210_209_01_gt2l.h5
# data/ATL06_20190101001723_00540210_209_01_gt2r.h5
# data/ATL06_20190101001723_00540210_209_01_gt3l.h5
# data/ATL06_20190101001723_00540210_209_01_gt3r.h5
# data/ATL06_20190101002504_00540211_209_01.h5
# data/ATL06_20190101002504_00540211_209_01_gt1l.h5
# data/ATL06_20190101002504_00540211_209_01_gt1r.h5
# data/ATL06_20190101002504_00540211_209_01_gt2l.h5
# data/ATL06_20190101002504_00540211_209_01_gt2r.h5
# data/ATL06_20190101002504_00540211_209_01_gt3l.h5
# data/ATL06_20190101002504_00540211_209_01_gt3r.h5
# data/ATL06_20190101003047_00540212_209_01.h5
# data/ATL06_20190101003047_00540212_209_01_gt1l.h5
# data/ATL06_20190101003047_00540212_209_01_gt1r.h5
# data/ATL06_20190101003047_00540212_209_01_gt2l.h5
# data/ATL06_20190101003047_00540212_209_01_gt2r.h5
# data/ATL06_20190101003047_00540212_209_01_gt3l.h5
# data/ATL06_20190101003047_00540212_209_01_gt3r.h5

# %%
# !h5ls -r data/ATL06_20190101001723_00540210_209_01_gt1l.h5
# Out:
# /                        Group
# /dac                     Dataset {33573}
# /f_sn                    Dataset {33573}
# /h_elv                   Dataset {33573}
# /h_rb                    Dataset {33573}
# /lat                     Dataset {33573}
# /lon                     Dataset {33573}
# /orbit                   Dataset {33573}
# /q_flg                   Dataset {33573}
# /rgt                     Dataset {33573}
# /s_elv                   Dataset {33573}
# /s_fg                    Dataset {33573}
# /snr                     Dataset {33573}
# /t_sec                   Dataset {33573}
# /t_year                  Dataset {33573}
# /tide_earth              Dataset {33573}
# /tide_load               Dataset {33573}
# /tide_ocean              Dataset {33573}
# /tide_pole               Dataset {33573}
# /trk_type                Dataset {33573}

# %% [markdown]
# ## Plot some data to check

# %% [markdown]
# * Plot track points within region to check
# * Plot track/beam profiles to check

# %% [markdown]
# Reading data now becomes trivial!!!

# %%
import matplotlib.pyplot as plt

def read_h5(fname, vnames=[]):
    """ Simple HDF5 reader. """
    with h5py.File(fname, 'r') as f:
        return [f[v][:] for v in vnames]

    
files = list_files_local('data/ATL06_20190101002504_00540211_209_01_gt*')

fig = plt.figure(figsize=(14,5))
ax1 = plt.subplot(121)
ax2 = plt.subplot(122)

for fname in files:

    lon, lat, t, h = read_h5(fname, ['lon', 'lat', 't_year', 'h_elv'])
    
    x, y = transform_coord(4326, 3031, lon, lat)
 
    ax1.plot(x, y, '.', label='%s' % fname[-7:-3])
    ax2.plot(t, h, '.', label='%s' % fname[-7:-3])
    
ax1.set_xlabel('x (m)')
ax1.set_ylabel('y (m)')
ax1.legend()
ax2.set_xlabel('time (yr)')
ax2.set_ylabel('height (m)')
ax2.legend()
plt.show()

# %% [markdown]
# ## Single program from the command line
#
# You can put all of the above (and more) into a single script and run it on the command line:

# %%
# !python readatl06.py -h
# Out:
# usage: readatl06.py [-h] [-o odir] [-f fmask] [-b w e s n] [-n njobs]
#                     [-p epsg_num] [-i index] [-g gran [gran ...]]
#                     ifile [ifile ...]
#
# Program for reading ICESat ATL06 data.
#
# positional arguments:
#   ifile               path for ifile(s) to read (.h5)
#
# optional arguments:
#   -h, --help          show this help message and exit
#   -o odir             path to output folder
#   -f fmask            name of raster file mask
#   -b w e s n          bounding box for geographical region (deg)
#   -n njobs            number of cores to use for parallel processing
#   -p epsg_num         projection: EPSG number (AnIS=3031, GrIS=3413)
#   -i index            provide mission index
#   -g gran [gran ...]  only select specific granule(s)

# %% [markdown]
# Try reading the ICESat-2 files in parallel from the command line:

# %%
# !python readatl06.py data/*_01.h5 -n 3
# Out:
# running parallel processing (3 jobs) ...
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# out -> data/ATL06_20190101001723_00540210_209_01_gt1l.h5
# out -> data/ATL06_20190101002504_00540211_209_01_gt1l.h5
# out -> data/ATL06_20190101003047_00540212_209_01_gt1l.h5
# out -> data/ATL06_20190101001723_00540210_209_01_gt1r.h5
# out -> data/ATL06_20190101003047_00540212_209_01_gt1r.h5
# out -> data/ATL06_20190101001723_00540210_209_01_gt2l.h5
# out -> data/ATL06_20190101002504_00540211_209_01_gt1r.h5
# out -> data/ATL06_20190101001723_00540210_209_01_gt2r.h5
# out -> data/ATL06_20190101003047_00540212_209_01_gt2l.h5
# out -> data/ATL06_20190101002504_00540211_209_01_gt2l.h5
# out -> data/ATL06_20190101001723_00540210_209_01_gt3l.h5
# out -> data/ATL06_20190101003047_00540212_209_01_gt2r.h5
# out -> data/ATL06_20190101001723_00540210_209_01_gt3r.h5
# [Parallel(n_jobs=3)]: Done   2 out of   4 | elapsed:    1.0s remaining:    1.0s
# out -> data/ATL06_20190101003047_00540212_209_01_gt3l.h5
# out -> data/ATL06_20190101002504_00540211_209_01_gt2r.h5
# out -> data/ATL06_20190101003047_00540212_209_01_gt3r.h5
# out -> data/ATL06_20190101002504_00540211_209_01_gt3l.h5
# out -> data/ATL06_20190101002504_00540211_209_01_gt3r.h5
# [Parallel(n_jobs=3)]: Done   4 out of   4 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   4 out of   4 | elapsed:    1.2s finished

# %%
# !cat readatl06.py
# Out:
# #!/usr/bin/env python
# # -*- coding: utf-8 -*-
#
# import re
# import sys
# import os
# import pyproj
# #import warnings
# import argparse
# #warnings.filterwarnings('ignore')
# import h5py
# import numpy as np
# from astropy.time import Time
# from scipy.ndimage import map_coordinates
#
# try:
#     from gdalconst import *
#     from osgeo import gdal, osr
# except:
#     print('No GDAL, proceeding without it!')
#
#
# def segDifferenceFilter(dh_fit_dx, h_li, tol=2):
#
#     dAT=20.
#
#     if h_li.shape[0] < 3:
#         mask = np.ones_like(h_li, dtype=bool)
#         return mask
#
#     EPplus  = h_li + dAT * dh_fit_dx
#     EPminus = h_li - dAT * dh_fit_dx
#
#     segDiff       = np.zeros_like(h_li)
#     segDiff[0:-1] = np.abs(EPplus[0:-1] - h_li[1:])
#     segDiff[1:]   = np.maximum(segDiff[1:], np.abs(h_li[0:-1] - EPminus[1:]))
#
#     mask = segDiff < tol
#
#     return mask
#
# def gps2dyr(time):
#     """ Converte from GPS time to decimal years. """
#     time = Time(time, format='gps')
#     time = Time(time, format='decimalyear').value
#
#     return time
#
# def list_files(path, endswith='.h5'):
#     """ List files in dir recursively."""
#     return [os.path.join(dpath, f)
#             for dpath, dnames, fnames in os.walk(path)
#             for f in fnames if f.endswith(endswith)]
#
# def transform_coord(proj1, proj2, x, y):
#     """Transform coordinates from proj1 to proj2 (EPSG num)."""
#
#     # Set full EPSG projection strings
#     proj1 = pyproj.Proj("+init=EPSG:"+proj1)
#     proj2 = pyproj.Proj("+init=EPSG:"+proj2)
#
#     # Convert coordinates
#     return pyproj.transform(proj1, proj2, x, y)
#
#
# def track_type(time, lat, tmax=1):
#     """
#         Determines ascending and descending tracks.
#         Defines unique tracks as segments with time breaks > tmax,
#         and tests whether lat increases or decreases w/time.
#     """
#
#     # Generate track segment
#     tracks = np.zeros(lat.shape)
#
#     # Set values for segment
#     tracks[0:np.argmax(np.abs(lat))] = 1
#
#     # Output index array
#     i_asc = np.zeros(tracks.shape, dtype=bool)
#
#     # Loop trough individual tracks
#     for track in np.unique(tracks):
#
#         # Get all points from an individual track
#         i_track, = np.where(track == tracks)
#
#         # Test tracks length
#         if len(i_track) < 2:
#             continue
#
#         # Test if lat increases (asc) or decreases (des) w/time
#         i_min = time[i_track].argmin()
#         i_max = time[i_track].argmax()
#         lat_diff = lat[i_track][i_max] - lat[i_track][i_min]
#
#         # Determine track type
#         if lat_diff > 0:
#             i_asc[i_track] = True
#
#     # Output index vector's
#     return i_asc, np.invert(i_asc)
#
#
# def geotiffread(ifile,metaData):
#     """Read raster from file."""
#
#     file = gdal.Open(ifile, GA_ReadOnly)
#
#     projection = file.GetProjection()
#     src = osr.SpatialReference()
#     src.ImportFromWkt(projection)
#     proj = src.ExportToWkt()
#
#     Nx = file.RasterXSize
#     Ny = file.RasterYSize
#
#     trans = file.GetGeoTransform()
#
#     dx = trans[1]
#     dy = trans[5]
#
#     if metaData == "A":
#
#         xp = np.arange(Nx)
#         yp = np.arange(Ny)
#
#         (Xp, Yp) = np.meshgrid(xp,yp)
#
#         X = trans[0] + (Xp+0.5)*trans[1] + (Yp+0.5)*trans[2]  #FIXME: bottleneck!
#         Y = trans[3] + (Xp+0.5)*trans[4] + (Yp+0.5)*trans[5]
#
#     if metaData == "P":
#
#         xp = np.arange(Nx)
#         yp = np.arange(Ny)
#
#         (Xp, Yp) = np.meshgrid(xp,yp)
#
#         X = trans[0] + Xp*trans[1] + Yp*trans[2]  #FIXME: bottleneck!
#         Y = trans[3] + Xp*trans[4] + Yp*trans[5]
#
#     band = file.GetRasterBand(1)
#
#     Z = band.ReadAsArray()
#
#     dx = np.abs(dx)
#     dy = np.abs(dy)
#
#     return X, Y, Z, dx, dy, proj
#
#
# def bilinear2d(xd,yd,data,xq,yq, **kwargs):
#     """Bilinear interpolation from grid."""
#
#     xd = np.flipud(xd)
#     yd = np.flipud(yd)
#     data = np.flipud(data)
#
#     xd = xd[0,:]
#     yd = yd[:,0]
#
#     nx, ny = xd.size, yd.size
#     (x_step, y_step) = (xd[1]-xd[0]), (yd[1]-yd[0])
#
#     assert (ny, nx) == data.shape
#     assert (xd[-1] > xd[0]) and (yd[-1] > yd[0])
#
#     if np.size(xq) == 1 and np.size(yq) > 1:
#         xq = xq*ones(yq.size)
#     elif np.size(yq) == 1 and np.size(xq) > 1:
#         yq = yq*ones(xq.size)
#
#     xp = (xq-xd[0])*(nx-1)/(xd[-1]-xd[0])
#     yp = (yq-yd[0])*(ny-1)/(yd[-1]-yd[0])
#
#     coord = np.vstack([yp,xp])
#
#     zq = map_coordinates(data, coord, **kwargs)
#
#     return zq
#
#
# # Output description of solution
# description = ('Program for reading ICESat ATL06 data.')
#
# # Define command-line arguments
# parser = argparse.ArgumentParser(description=description)
#
# parser.add_argument(
#         'ifiles', metavar='ifile', type=str, nargs='+',
#         help='path for ifile(s) to read (.h5)')
#
# parser.add_argument(
#         '-o', metavar=('odir'), dest='odir', type=str, nargs=1,
#         help='path to output folder',
#         default=[None])
#
# parser.add_argument(
#         '-f', metavar=('fmask'), dest='fmask', type=str, nargs=1,
#         help="name of raster file mask",
#         default=[None],)
#
# parser.add_argument(
#         '-b', metavar=('w','e','s','n'), dest='bbox', type=float, nargs=4,
#         help=('bounding box for geographical region (deg)'),
#         default=[None],)
#
# parser.add_argument(
#         '-n', metavar=('njobs'), dest='njobs', type=int, nargs=1,
#         help="number of cores to use for parallel processing",
#         default=[1],)
#
# parser.add_argument(
#         '-p', metavar=('epsg_num'), dest='proj', type=str, nargs=1,
#         help=('projection: EPSG number (AnIS=3031, GrIS=3413)'),
#         default=['3031'],)
#
# parser.add_argument(
#         '-i', metavar=('index'), dest='index', type=int, nargs=1,
#         help=('provide mission index'),
#         default=[None],)
#
# parser.add_argument(
#         '-g', metavar=('gran'), dest='gran', type=str, nargs='+',
#         help='only select specific granule(s)',
#         default=[None],)
#
# # Parser argument to variable
# args = parser.parse_args()
#
# # Read input from terminal
# ifiles = args.ifiles
# opath_ = args.odir[0]
# bbox   = args.bbox
# njobs  = args.njobs[0]
# fmask  = args.fmask[0]
# proj   = args.proj[0]
# index  = args.index[0]
# gran   = args.gran
#
# # Get filelist of data to process
# #ifiles = list_files(ipath,endswith='.h5')
#
# # Beam namnes
# group = ['/gt1l','/gt1r','/gt2l','/gt2r','/gt3l','/gt3r']
#
# # Beam indicies
# beams = [1, 2, 3, 4, 5, 6]
#
# # Create beam index container
# orb_i = 0
#
# # Select the granules
# if gran[0]: gran = np.asarray(gran).astype(int)
#
# # Raster mask
# if fmask is not None:
#
#     print('Reading raster mask ....')
#     if fmask.endswith('.tif'):
#
#         # Read in masking grid
#         (Xm, Ym, Zm, dX, dY, Proj) = geotiffread(fmask, "A")
#
#     else:
#
#         # Read Hdf5 from memory
#         Fmask = h5py.File(fmask, 'r')
#
#         # Get variables
#         Xm = Fmask['X'][:]
#         Ym = Fmask['Y'][:]
#         Zm = Fmask['Z'][:]
#
# # Loop trough and open files
# def main(ifile, n=''):
#
#     if gran[0] is not None:
#         gran_str = ifile.split('_')[-3]
#
#         n_str = len(gran_str)
#
#         gran_num = int(gran_str[-2:n_str])
#
#         if np.all(gran_num != gran):
#             return
#
#     # Access global variable
#     global orb_i
#
#     # Check if we already processed the file
#     if ifile.endswith('_A.h5') or ifile.endswith('_D.h5'):
#         return
#
#     # Beam flag error
#     flg_read_err = False
#
#     # Loop trough beams
#     for k in range(len(group)):
#
#         # Load full data into memory (only once)
#         with h5py.File(ifile, 'r') as fi:
#
#             # Try to read vars
#             try:
#
#                 # Read in varibales of interest (more can be added!)
#                 dac  = fi[group[k]+'/land_ice_segments/geophysical/dac'][:]
#                 lat  = fi[group[k]+'/land_ice_segments/latitude'][:]
#                 lon  = fi[group[k]+'/land_ice_segments/longitude'][:]
#                 h_li = fi[group[k]+'/land_ice_segments/h_li'][:]
#                 s_li = fi[group[k]+'/land_ice_segments/h_li_sigma'][:]
#                 t_dt = fi[group[k]+'/land_ice_segments/delta_time'][:]
#                 flag = fi[group[k]+'/land_ice_segments/atl06_quality_summary'][:]
#                 s_fg = fi[group[k]+'/land_ice_segments/fit_statistics/signal_selection_source'][:]
#                 snr  = fi[group[k]+'/land_ice_segments/fit_statistics/snr_significance'][:]
#                 h_rb = fi[group[k]+'/land_ice_segments/fit_statistics/h_robust_sprd'][:]
#                 f_sn = fi[group[k]+'/land_ice_segments/geophysical/bsnow_conf'][:]
#                 tref = fi['/ancillary_data/atlas_sdp_gps_epoch'][:]
#                 rgt  = fi['/orbit_info/rgt'][:]*np.ones(len(lat))
#                 dh_fit_dx = fi[group[k]+'/land_ice_segments/fit_statistics/dh_fit_dx'][:]
#
#                 # Tide corrections
#                 tide_earth = fi[group[k]+'/land_ice_segments/geophysical/tide_earth'][:]
#                 tide_load  = fi[group[k]+'/land_ice_segments/geophysical/tide_load'][:]
#                 tide_ocean = fi[group[k]+'/land_ice_segments/geophysical/tide_ocean'][:]
#                 tide_pole  = fi[group[k]+'/land_ice_segments/geophysical/tide_pole'][:]
#
#             except:
#
#                 # Set error flag
#                 flg_read_err = True
#                 pass
#
#         # Continue to next beam
#         if flg_read_err: return
#
#         # Remove DAC
#         #h_li = h_li + np.float64(dac)     ####### NOTE WE ARE REMOVING DAC FOR R205
#
#         # Make sure its a 64 bit float
#         dh_fit_dx = np.float64(dh_fit_dx)
#
#         # Apply bounding box
#         if bbox[0]:
#
#             # Extract bounding box
#             (lonmin, lonmax, latmin, latmax) = bbox
#
#             # Select data inside bounding box
#             ibox = (lon >= lonmin) & (lon <= lonmax) & (lat >= latmin) & (lat <= latmax)
#
#             # Set mask container
#             i_m  = np.ones(lat.shape)
#
#         # Raster mask
#         elif fmask is not None:
#
#
#             # Determine projection
#             if proj != '4326':
#
#                 # Reproject coordinates
#                 (x, y) = transform_coord('4326', proj, lon, lat)
#
#             else:
#
#                 # Keep lon/lat
#                 x, y = lon, lat
#
#             # Interpolation of grid to points for masking
#             i_m = bilinear2d(Xm, Ym, Zm, x.T, y.T, order=1)
#
#             # Set all NaN's to zero
#             i_m[np.isnan(i_m)] = 0
#
#         else:
#
#             # Select all boolean
#             ibox = np.ones(lat.shape,dtype=bool)
#
#             # Set mask container
#             i_m  = np.ones(lat.shape)
#
#         # Compute segment difference mask
#         mask = segDifferenceFilter(dh_fit_dx, h_li, tol=2)
#
#         # Copy original flag
#         q_flag = flag.copy()
#
#         # Quality flag, only keep good data and data inside box
#         # flag = (s_fg == 0) & (s_li < 1) & (h_rb < 1) & (np.abs(h_li) < 10e3) & (i_m > 0)
#         flag = (flag == 0) & (np.abs(h_li) < 10e3) & (i_m > 0) & mask
#
#         # Only keep good data
#         lat, lon, h_li, s_li, t_dt, h_rb, s_fg, snr, q_flag, f_sn, tide_earth, tide_load, tide_ocean, tide_pole, dac,\
#             rgt = lat[flag], lon[flag], h_li[flag],s_li[flag], t_dt[flag], h_rb[flag], s_fg[flag], \
#                 snr[flag], q_flag[flag], f_sn[flag], tide_earth[flag], tide_load[flag], \
#                     tide_ocean[flag], tide_pole[flag], dac[flag], rgt[flag]
#
#         # Test for no data
#         if len(h_li) == 0: return
#
#         # Time in decimal years
#         t_li = gps2dyr(t_dt + tref)
#
#         # Time in GPS seconds
#         t_gps = t_dt + tref
#
#         # Determine track type
#         (i_asc, i_des) = track_type(t_li, lat)
#
#         # Determine if to use the index
#         if index is not None:
#
#             # Add unique mission identifier
#             orb_unique = np.char.add(str(index), str(orb_i)).astype('int')
#
#             # Create orbit number
#             orb = np.full(t_gps.shape, orb_unique)
#
#         else:
#
#             # Create orbit number
#             orb = np.full(t_gps.shape, orb_i)
#
#         # Construct output name and path
#         ipath, fname = os.path.split(ifile)
#         name, ext = os.path.splitext(fname)
#         opath = opath_ if opath_ else ipath
#         ofile = os.path.join(opath, name +'_'+group[k][1:]+ ext)
#
#         with h5py.File(ofile, 'w') as fa:
#
#             # Save ascending vars
#             fa['orbit'] = orb
#             fa['lon'] = lon
#             fa['lat'] = lat
#             fa['h_elv'] = h_li
#             fa['s_elv'] = s_li
#             fa['t_year'] = t_li
#             fa['h_rb'] = h_rb
#             fa['s_fg'] = s_fg
#             fa['snr'] = snr
#             fa['q_flg'] = q_flag
#             fa['f_sn'] = f_sn
#             fa['t_sec'] = t_gps
#             fa['tide_load'] = tide_load
#             fa['tide_ocean'] = tide_ocean
#             fa['tide_pole'] = tide_pole
#             fa['tide_earth'] = tide_earth
#             fa['dac'] = dac
#             fa['rgt'] = rgt
#             fa['trk_type'] = i_asc
#
#         # Name of file
#         try:
#             print('out ->', ofile)
#         except:
#             print('Not processed!')
#
#         # Update orbit number
#         orb_i += 1
#
# # Run main program
# if njobs == 1:
#
#     print('running sequential processing ...')
#     [main(f) for f in ifiles]
#
# else:
#
#     print('running parallel processing (%d jobs) ...' % njobs)
#     from joblib import Parallel, delayed
#     Parallel(n_jobs=njobs, verbose=5)(delayed(main)(f, n) for n, f in enumerate(ifiles))
